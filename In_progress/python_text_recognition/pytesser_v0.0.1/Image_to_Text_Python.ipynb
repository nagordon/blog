# %% [markdown]
# Image to text recognition with python
#
# this only works in windows!
#
# Lets download [pytesser](https://pytesser.googlecode.com/files/pytesser_v0.0.1.zip)
# Unzip the file

# %%
cd pytesser_v0.0.1/
# Out:
# [Error 2] The system cannot find the file specified: u'pytesser_v0.0.1/'
# C:\Users\ngordon\Desktop\python_text_recognition\pytesser_v0.0.1

# %%
ls *png *tif
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5033-5C23
#
#  Directory of C:\Users\ngordon\Desktop\python_text_recognition\pytesser_v0.0.1
#
#
#  Directory of C:\Users\ngordon\Desktop\python_text_recognition\pytesser_v0.0.1
#
# 04/30/2015  10:31 AM             1,410 fnord.tif
# 04/30/2015  10:31 AM            20,607 fonts_test.png
# 05/07/2015  04:12 PM           405,936 img_to_text.png
# 04/30/2015  10:31 AM            38,668 phototest.tif
# 04/30/2015  11:18 AM           347,444 StudioFilePPTX0001003.png
# 04/30/2015  10:29 AM           525,189 txttoimg.png
# 04/30/2015  10:41 AM           759,524 txttoimg.tif
#                7 File(s)      2,098,778 bytes
#                0 Dir(s)  92,163,448,832 bytes free

# %%
pwd
# Out:
# u'C:\\Users\\ngordon\\Desktop\\python_text_recognition\\pytesser_v0.0.1'

# %%
from pytesser import *
from PIL import Image
from IPython.display import Image as Iimage

# %%
imgfile = 'fonts_test.png'
Iimage(filename=imgfile)

# %%
print image_to_string(Image.open(imgfile))
# Out:
# 12 pt
# And Arnazwngw few dwscotheques provwde jukeboxes
# Tames Amazmgly few dnscotheques pmvxde Jukeboxes
# 24 pt:
# Arial: Amazingly few discotheques
# provide jul<ebo><es.
# Courier: Ama zimgly few
# discotheque S provide
# j u k e b ox e S .
# Times: Amazingly few discotheques provide
# jukeboxes.

# %%
imgfile = 'StudioFilePPTX0001003.png'
Iimage(filename=imgfile)

# %%
print image_to_string( Image.open(imgfile))
# Out:
# I Importing Composite Properties from the Composite Design Workbench
# rt The analysis type is dictated by the information availablefrom the Composite
# Design workbench; for example, if the composite properties were created by
# zones. you must use the By zone analysis type.
# r Ifyou selected By ply, you can toggle on Transfer producibility to include
# manufacturing parametersin the composite. The producibility parameters attempt
# to align the fiberswith the way a part must be formed based on a producibility
# analysis in the Composite Design workbench.
# t The differences in results dueto this option will be more apparent if the part has
# surfaces with significant cuwature such as a hemisphere. If you do not use this
# option, fiber directions are transferred by basic projection onto the part surfaces.
# rt Support for composite properties also includes several new output variables for
# use in analyzing composite failure modes. The new variables measure composite
# ...

# %%
imgfile = 'three.png'
Iimage(filename=imgfile)

# %%
print image_to_string( Image.open(imgfile))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-34-bb826d8ec540> in <module>()
# ----> 1 print image_to_string( Image.open(imgfile))
#
# C:\Users\ngordon\Desktop\python_text_recognition\pytesser_v0.0.1\pytesser.pyc in image_to_string(im, cleanup)
#      28 	If cleanup=True, delete scratch files after operation."""
#      29         try:
# ---> 30                 util.image_to_scratch(im, scratch_image_name)
#      31                 call_tesseract(scratch_image_name, scratch_text_name_root)
#      32                 text = util.retrieve_text(scratch_text_name_root)
#
# C:\Users\ngordon\Desktop\python_text_recognition\pytesser_v0.0.1\util.pyc in image_to_scratch(im, scratch_image_name)
#       5 def image_to_scratch(im, scratch_image_name):
#       6         """Saves image in memory to scratch file.  .bmp format will be read correctly by Tesseract"""
# ...
